# %%
import sciencebasepy
import os
from pathlib import Path

# path where data will be downloaded
dir = Path("/beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release")
# login routine follows instructions here: https://code.usgs.gov/sas/sdm/sciencebasepy/-/blob/master/Authentication%20Options.ipynb
sb = sciencebasepy.SbSession()
sb.get_token()
# Out:
# A browser window/tab should momentarily open with ScienceBase Manager
# Sign in using active directory or login.gov
# Click the user icon in the upper right and select 'Copy API token'
# This copies the token to your clipboard
# Use this value in the add_token function as the token_json parameter

# %%
token = {
    "access_token": "eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJCMWJfZFBNR3BWY09hT253dU0zQThnSGF2Mzd5U1Y0OXJaLUZ2U2gtaXRNIn0.....n1_guihJuYIxOyyCaxWaAO1Lfbjb2pbRLDhqiluIqPbrrWP-78PfVoN8blJStSmJKlBP-S0Y5-UUtyW2iuZbr5PJlM_pfM_v_y5SkTi1vswZoh-gRVV-0bAs99IqS6buqdtDGaB68Bp_TpnsnA21PKKFD4ZKJdK1BzA5wM-_ae8O_KencD3SApDHQe0ACMeJyMIFfsXow6h5GQ4tp0NtwiIGQ1zIQjl9mq5_ls5gJUInRP4T1tlY54GKqGQ638NggyI6MOTGf2ZhPF6SJoUNv5FvDxGpl6w11N0obiFcRA44--RfRRqW_8iYLowkOsl4SFxKYP7cYLvWMLT1bWDLXg",
    "refresh_token": "eyJhbGciOiJIUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJkMmMyMmZmMy1mZjIxLTQ4NjQtYjJlMS04NTQ1ZWJlNmU0NjkifQ.....cn0K3ch6Rze3hNr8ehGyacOLkRSChYX_c0iHug6HYNc",
}

# %%
sb.add_token(token)
sb.is_logged_in()
# Out:
# True

# %%
# the data release item on ScienceBase (https://www.sciencebase.gov/catalog/item/67ead89cd34ed02007f8357f)
item = "67ead89cd34ed02007f8357f"
item_json = sb.get_item(item)
print(item_json["title"])
# Out:
# The influence of fire-fuel feedbacks on boreal forest fire regimes under future climate change

# %%
files = sb.get_item_files(item_json, dir, progress_bar=True)
files
# Out:
# downloading https://www.sciencebase.gov/catalog/file/get/67ead89cd34ed02007f8357f?f=__disk__e8%2Fc7%2F7a%2Fe8c77a6377a6c8dd200e8ac8877a4bb52d4fe54e to /beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release/jags-results.zip
# [==================================================] 100%
# downloading https://www.sciencebase.gov/catalog/file/get/67ead89cd34ed02007f8357f?f=__disk__f5%2Fe8%2F0d%2Ff5e80d3939ce9cf0503f27a8c9c16b0b2243f05c to /beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release/AK_Canada_aea.prj
# [==================================================] 100%
# downloading https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6ssw503a30xpr9xoz4k6s to /beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release/bias_corrected_CNRM-CM6-1-HR.tar.gz
# [============================================================================================================] 217%
# downloading https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6swjk03a40xpr4zbn2z7j to /beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release/bias_corrected_EC-Earth3-Veg.tar.gz
# [============================================================================================================] 217%
# downloading https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6t0qt03a50xpr7n3f9pmd to /beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release/bias_corrected_MPI-ESM1-2-HR.tar.gz
# [============================================================================================================] 217%
# downloading https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6t4x703a60xprfg6qaqv7 to /beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release/bias_corrected_MRI-ESM2-0.tar.gz
# [============================================================================================================] 217%
# downloading https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6tc5v03a70xpr353r0rdc to /beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release/cffdrs_CNRM-CM6-1-HR.tar.gz
# [============================================================================================================] 217%
# downloading https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6tl0k03a80xpr42ddf2h1 to /beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release/cffdrs_EC-Earth3-Veg.tar.gz
# [============================================================================================================] 217%
# downloading https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6tpyk03a90xprcrybctkg to /beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release/cffdrs_MPI-ESM1-2-HR.tar.gz
# [============================================================================================================] 217%
# downloading https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6tu8003aa0xprgjfycgrk to /beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release/cffdrs_MRI-ESM2-0.tar.gz
# [============================================================================================================] 217%
# downloading https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6tx4v03ab0xpr7adq3c3q to /beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release/cffdrs_era5.tar.gz
# [============================================================================================================] 217%
# downloading https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6tzhm03ac0xprej6h5gj8 to /beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release/cffdrs_stats.tar.gz
# [============================================================================================================] 217%
# downloading https://www.sciencebase.gov/catalog/file/get/67ead89cd34ed02007f8357f?f=__disk__37%2F48%2F5f%2F37485f1350a64df9c352af663e216730a30c17b5 to /beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release/data-structure-readme.md
# [==================================================] 100%
# downloading https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf7plnh03al0xprel9ncyj9 to /beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release/veg.zip
# [============================================================================================================] 217%
# downloading https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf7pp3g03am0xpr9kdiacjn to /beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release/model_results.zip
# [============================================================================================================] 217%
# downloading https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf7puqs03an0xpr1y25493v to /beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release/fire.zip
# [============================================================================================================] 217%
# downloading https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf7pvg003ao0xprerkc0vnz to /beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release/ecoregions.zip
# [============================================================================================================] 217%
# downloading https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf7pwaa03ap0xpr7zdg5s4w to /beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release/dataframes.tar.gz
# [============================================================================================================] 217%
# downloading https://www.sciencebase.gov/catalog/file/get/67ead89cd34ed02007f8357f?f=__disk__d1%2F1b%2Fc6%2Fd11bc63ef6a1a7a24b58f8976dd42b9896c316cd to /beegfs/CMIP6/arctic-cmip6/cmip6_fwi/cmip6_fwi/data_release/ak-boreal-metadata.xml
# [==================================================] 100%
# [{'url': 'https://www.sciencebase.gov/catalog/file/get/67ead89cd34ed02007f8357f?f=__disk__e8%2Fc7%2F7a%2Fe8c77a6377a6c8dd200e8ac8877a4bb52d4fe54e',
#   'name': 'jags-results.zip',
#   'size': 26589017,
#   'originalMetadata': False,
#   'contentType': 'application/zip'},
#  {'url': 'https://www.sciencebase.gov/catalog/file/get/67ead89cd34ed02007f8357f?f=__disk__f5%2Fe8%2F0d%2Ff5e80d3939ce9cf0503f27a8c9c16b0b2243f05c',
#   'name': 'AK_Canada_aea.prj',
#   'size': 1367,
#   'originalMetadata': False,
#   'contentType': 'text/plain'},
#  {'url': 'https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6ssw503a30xpr9xoz4k6s',
#   'name': 'bias_corrected_CNRM-CM6-1-HR.tar.gz',
#   'size': 7109339415,
#   'originalMetadata': False,
#   'contentType': 'application/gzip'},
#  {'url': 'https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6swjk03a40xpr4zbn2z7j',
#   'name': 'bias_corrected_EC-Earth3-Veg.tar.gz',
#   'size': 7219380023,
#   'originalMetadata': False,
#   'contentType': 'application/gzip'},
#  {'url': 'https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6t0qt03a50xpr7n3f9pmd',
#   'name': 'bias_corrected_MPI-ESM1-2-HR.tar.gz',
#   'size': 7200477550,
#   'originalMetadata': False,
#   'contentType': 'application/gzip'},
#  {'url': 'https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6t4x703a60xprfg6qaqv7',
#   'name': 'bias_corrected_MRI-ESM2-0.tar.gz',
#   'size': 7255294454,
#   'originalMetadata': False,
#   'contentType': 'application/gzip'},
#  {'url': 'https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6tc5v03a70xpr353r0rdc',
#   'name': 'cffdrs_CNRM-CM6-1-HR.tar.gz',
#   'size': 11224101715,
#   'originalMetadata': False,
#   'contentType': 'application/gzip'},
#  {'url': 'https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6tl0k03a80xpr42ddf2h1',
#   'name': 'cffdrs_EC-Earth3-Veg.tar.gz',
#   'size': 11368794088,
#   'originalMetadata': False,
#   'contentType': 'application/gzip'},
#  {'url': 'https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6tpyk03a90xprcrybctkg',
#   'name': 'cffdrs_MPI-ESM1-2-HR.tar.gz',
#   'size': 11297610999,
#   'originalMetadata': False,
#   'contentType': 'application/gzip'},
#  {'url': 'https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6tu8003aa0xprgjfycgrk',
#   'name': 'cffdrs_MRI-ESM2-0.tar.gz',
#   'size': 11060139230,
#   'originalMetadata': False,
#   'contentType': 'application/gzip'},
#  {'url': 'https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6tx4v03ab0xpr7adq3c3q',
#   'name': 'cffdrs_era5.tar.gz',
#   'size': 3917342257,
#   'originalMetadata': False,
#   'contentType': 'application/gzip'},
#  {'url': 'https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf6tzhm03ac0xprej6h5gj8',
#   'name': 'cffdrs_stats.tar.gz',
#   'size': 184197387,
#   'originalMetadata': False,
#   'contentType': 'application/gzip'},
#  {'url': 'https://www.sciencebase.gov/catalog/file/get/67ead89cd34ed02007f8357f?f=__disk__37%2F48%2F5f%2F37485f1350a64df9c352af663e216730a30c17b5',
#   'name': 'data-structure-readme.md',
#   'size': 5980,
#   'originalMetadata': False,
#   'contentType': 'text/x-web-markdown'},
#  {'url': 'https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf7plnh03al0xprel9ncyj9',
#   'name': 'veg.zip',
#   'size': 2798698093,
#   'originalMetadata': False,
#   'contentType': 'application/zip'},
#  {'url': 'https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf7pp3g03am0xpr9kdiacjn',
#   'name': 'model_results.zip',
#   'size': 301819867,
#   'originalMetadata': False,
#   'contentType': 'application/zip'},
#  {'url': 'https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf7puqs03an0xpr1y25493v',
#   'name': 'fire.zip',
#   'size': 588817512,
#   'originalMetadata': False,
#   'contentType': 'application/zip'},
#  {'url': 'https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf7pvg003ao0xprerkc0vnz',
#   'name': 'ecoregions.zip',
#   'size': 3986305,
#   'originalMetadata': False,
#   'contentType': 'application/zip'},
#  {'url': 'https://sciencebase.usgs.gov/manager/item/67ead89cd34ed02007f8357f/file/cmcf7pwaa03ap0xpr7zdg5s4w',
#   'name': 'dataframes.tar.gz',
#   'size': 6160045,
#   'originalMetadata': False,
#   'contentType': 'application/gzip'},
#  {'url': 'https://www.sciencebase.gov/catalog/file/get/67ead89cd34ed02007f8357f?f=__disk__d1%2F1b%2Fc6%2Fd11bc63ef6a1a7a24b58f8976dd42b9896c316cd',
#   'name': 'ak-boreal-metadata.xml',
#   'size': 84943,
#   'originalMetadata': True,
#   'contentType': 'application/fgdc+xml'}]
